# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports

import os
import requests # for ollama
import json
from dotenv import load_dotenv
from IPython.display import Markdown, display, update_display
from scraper import fetch_website_links, fetch_website_contents
from openai import OpenAI

# %% [markdown]
# run in terminal: ollama serve

# %%
requests.get("http://localhost:11434").content # should print "Ollama is running"
# Out:
# b'Ollama is running'

# %%
# constants
MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
system_prompt = "You are a helpful technical tutor who answers questions about python code, software engineering, data science and LLMs"
user_prompt = "Please give a detailed explanation to the following question: " + question

messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": user_prompt}]

# %%
# Get Llama 3.2 to answer
def stream_answer():
    stream = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=messages,
        stream=True 
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)

    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_answer()
# Out:
# **Explanation of the Code**
#
# The given code snippet is written in Python and utilizes several advanced concepts, including generators, dictionary methods, and list comprehensions. Let's break it down:
#
# ### Key Components
#
# 1. `{book.get("author") for book in books if book.get("author")}`: This part is a **list comprehension** combined with an **iterable expression** inside the dictionary `get` method.
# 2. `yield from`: A keyword used to indicate that the enclosing function should delegate iteration to this iterator.
#
# ### Step-by-Step Explanation
#
# 1. `{... for book in books if ...}` is an iterable expression that creates a sequence of values. The sequence will be:
# 	* `book.get("author")` (accessing a specific key-value pair from the `book` dictionary)
# 	* Only included in the sequence if `book.get("author")` exists as a dictionary value and its presence in the sequence is governed by the condition `if book.get("author)`
# 2. The resulting sequence of values is then fed into the `yield from` expression.
# 3. When this code is executed, it starts to evaluate the iterable expression inside the `yield from` statement.
#
# ### How it Works Internally
#
# Internally, when you use a generator expression like `{...}` in conjunction with `yield from`, Python performs the following steps:
#
# 1. Evaluates the input iterable (in this case, a dictionary iterator using `for book in books`)
# 2. Iterates through the dictionary, yielding each value returned by `book.get("author")`: if it exists and meets the condition
# 3. When the generated values are exhausted (i.e., there are no more items in the dictionary), control flow returns to the caller.
# 4. The `yield from` expression then yields a new iterator that iterates over those values.
#
# ### Example Usage
#
# ```python
# # Sample data:
# books = [
#     {"id": 1, "author": "John Doe"},
#     {"id": 2},
#     {"id": 3, "author": "Jane Smith"}
# ]
#
# # Filtered authors list comprehension using yield from
# def get_authors(books):
#     return (book["author"] for book in books if book.get("author"))
#
# authors = get_authors(books)
# for author in authors:
#     print(author)  # Output: John Doe, Jane Smith
#
# # Without generator expression and yield from
# original_code = [
#     book["author"]
#     for book in books
#     if "author" in book
# ]
#
# original_authors = original_code[:]
# for author in original_authors:
#     print(author)  # Output: John Doe, Jane Smith
# ```
#
# The example uses `books` as a list of dictionaries with or without an `"author"` field. By using `yield from`, the code creates a sequence of authors iteratively and efficiently leverages the data's structure (dictionary). This approach is particularly helpful when dealing with large datasets, where iterating through them isn't always feasible.
#
# ### Note
#
# While you could achieve similar results using a normal loop or list comprehension without `yield from`, this method has several benefits:
#
# 1. Memory efficiency
# 2. Simplified code
# 3. Greater flexibility

# %%
# Get gpt to answer, with streaming
def stream_answer():
    stream = openai.chat.completions.create(
        model=MODEL_GPT,
        messages=messages,
        stream=True 
    )    
    response = ""
    display_handle = display(Markdown(""), display_id=True)

    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        update_display(Markdown(response), display_id=display_handle.display_id)
